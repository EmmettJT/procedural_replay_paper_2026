# %% [markdown]
# # import

# %%
from Utilities.utils import *

# Get the current working directory
current_working_dir = os.path.join(Path(os.getcwd()).parent,'data') 
ED10_data_dict = load_h5(os.path.join(current_working_dir,r"ED10_data.h5"))

X_scaled = ED10_data_dict['bts_X_scaled']
Y_scaled = ED10_data_dict['bts_Y_scaled']

# %% [markdown]
# # figure A - D

# %%
# plot scree 
full_corrs,null_corrs_all = plot_cannon_corr(X_scaled, Y_scaled)
# cross correlations
fold_cross_val(full_corrs,null_corrs_all,0)
fold_cross_val(full_corrs,null_corrs_all,1)
fold_cross_val(full_corrs,null_corrs_all,3)

# %% [markdown]
# # figure E & F

# %%
redundancy(X_scaled,Y_scaled,1)
redundancy(X_scaled,Y_scaled,2)

# %% [markdown]
# # figure G & H

# %%
stb_X_scaled = ED10_data_dict['stb_X_scaled']
stb_Y_scaled = ED10_data_dict['stb_Y_scaled']

# %%
# plot scree 
full_corrs,null_corrs_all = plot_cannon_corr(stb_X_scaled, stb_Y_scaled)
# cross correlations
fold_cross_val(full_corrs,null_corrs_all,0)

# %% [markdown]
# # figure I

# %%
redundancy(stb_X_scaled,stb_Y_scaled,1)
